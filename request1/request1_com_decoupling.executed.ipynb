# %% [markdown]
# # Request 1: COM Decoupling
#
# This notebook reproduces the symbolic COM reduction through quadrupole order and checks the two spherical benchmark profiles discussed in the note.

# %%
import request1_com_decoupling as r1

sym = r1.build_symbolic_results()
sym["L_com"]
# Out:
# -I11*Derivative(Phi(X1, X2, X3), (X1, 2))/2 - I12*Derivative(Phi(X1, X2, X3), X1, X2) - I13*Derivative(Phi(X1, X2, X3), X1, X3) - I22*Derivative(Phi(X1, X2, X3), (X2, 2))/2 - I23*Derivative(Phi(X1, X2, X3), X2, X3) - I33*Derivative(Phi(X1, X2, X3), (X3, 2))/2 + M*V1**2/2 + M*V2**2/2 + M*V3**2/2 - M*Phi(X1, X2, X3) + T_int + U_self*lambda - U_self

# %%
for i, eq in enumerate(sym["euler_lagrange"], start=1):
    print(f"EL_{i} = {eq}")

for i, acc in enumerate(sym["acceleration_rhs"], start=1):
    print(f"a_{i} = {acc}")
# Out:
# EL_1 = A1*M + I11*Derivative(Phi(X1, X2, X3), (X1, 3))/2 + I12*Derivative(Phi(X1, X2, X3), (X1, 2), X2) + I13*Derivative(Phi(X1, X2, X3), (X1, 2), X3) + I22*Derivative(Phi(X1, X2, X3), X1, (X2, 2))/2 + I23*Derivative(Phi(X1, X2, X3), X1, X2, X3) + I33*Derivative(Phi(X1, X2, X3), X1, (X3, 2))/2 + M*Derivative(Phi(X1, X2, X3), X1)
# EL_2 = A2*M + I11*Derivative(Phi(X1, X2, X3), (X1, 2), X2)/2 + I12*Derivative(Phi(X1, X2, X3), X1, (X2, 2)) + I13*Derivative(Phi(X1, X2, X3), X1, X2, X3) + I22*Derivative(Phi(X1, X2, X3), (X2, 3))/2 + I23*Derivative(Phi(X1, X2, X3), (X2, 2), X3) + I33*Derivative(Phi(X1, X2, X3), X2, (X3, 2))/2 + M*Derivative(Phi(X1, X2, X3), X2)
# EL_3 = A3*M + I11*Derivative(Phi(X1, X2, X3), (X1, 2), X3)/2 + I12*Derivative(Phi(X1, X2, X3), X1, X2, X3) + I13*Derivative(Phi(X1, X2, X3), X1, (X3, 2)) + I22*Derivative(Phi(X1, X2, X3), (X2, 2), X3)/2 + I23*Derivative(Phi(X1, X2, X3), X2, (X3, 2)) + I33*Derivative(Phi(X1, X2, X3), (X3, 3))/2 + M*Derivative(Phi(X1, X2, X3), X3)
# a_1 = (-I11*Derivative(Phi(X1, X2, X3), (X1, 3))/2 - I12*Derivative(Phi(X1, X2, X3), (X1, 2), X2) - I13*Derivative(Phi(X1, X2, X3), (X1, 2), X3) - I22*Derivative(Phi(X1, X2, X3), X1, (X2, 2))/2 - I23*Derivative(Phi(X1, X2, X3), X1, X2, X3) - I33*Derivative(Phi(X1, X2, X3), X1, (X3, 2))/2 - M*Derivative(Phi(X1, X2, X3), X1))/M
# a_2 = (-I11*Derivative(Phi(X1, X2, X3), (X1, 2), X2)/2 - I12*Derivative(Phi(X1, X2, X3), X1, (X2, 2)) - I13*Derivative(Phi(X1, X2, X3), X1, X2, X3) - I22*Derivative(Phi(X1, X2, X3), (X2, 3))/2 - I23*Derivative(Phi(X1, X2, X3), (X2, 2), X3) - I33*Derivative(Phi(X1, X2, X3), X2, (X3, 2))/2 - M*Derivative(Phi(X1, X2, X3), X2))/M
# a_3 = (-I11*Derivative(Phi(X1, X2, X3), (X1, 2), X3)/2 - I12*Derivative(Phi(X1, X2, X3), X1, X2, X3) - I13*Derivative(Phi(X1, X2, X3), X1, (X3, 2)) - I22*Derivative(Phi(X1, X2, X3), (X2, 2), X3)/2 - I23*Derivative(Phi(X1, X2, X3), X2, (X3, 2)) - I33*Derivative(Phi(X1, X2, X3), (X3, 3))/2 - M*Derivative(Phi(X1, X2, X3), X3))/M

# %%
sphere = r1.uniform_sphere_results()
poly = r1.n1_polytrope_results()

sphere["second_moment"], sphere["quadrupole"], poly["second_moment"], poly["quadrupole"]
# Out:
# (Matrix([
#  [M_sphere*R**2/5,               0,               0],
#  [              0, M_sphere*R**2/5,               0],
#  [              0,               0, M_sphere*R**2/5]]),
#  Matrix([
#  [0, 0, 0],
#  [0, 0, 0],
#  [0, 0, 0]]),
#  Matrix([
#  [M_poly*R**2*(-6 + pi**2)/(3*pi**2),                                  0,                                  0],
#  [                                 0, M_poly*R**2*(-6 + pi**2)/(3*pi**2),                                  0],
#  [                                 0,                                  0, M_poly*R**2*(-6 + pi**2)/(3*pi**2)]]),
#  Matrix([
#  [0, 0, 0],
#  [0, 0, 0],
#  [0, 0, 0]]))

# %%
r1.print_summary()
# Out:
# === General COM-reduced Lagrangian ===
# -I11*Derivative(Phi(X1, X2, X3), (X1, 2))/2 - I12*Derivative(Phi(X1, X2, X3), X1, X2) - I13*Derivative(Phi(X1, X2, X3), X1, X3) - I22*Derivative(Phi(X1, X2, X3), (X2, 2))/2 - I23*Derivative(Phi(X1, X2, X3), X2, X3) - I33*Derivative(Phi(X1, X2, X3), (X3, 2))/2 + M*V1**2/2 + M*V2**2/2 + M*V3**2/2 - M*Phi(X1, X2, X3) + T_int + U_self*lambda - U_self
#
# === Euler-Lagrange equations for the COM coordinates ===
# EL_1 = A1*M + I11*Derivative(Phi(X1, X2, X3), (X1, 3))/2 + I12*Derivative(Phi(X1, X2, X3), (X1, 2), X2) + I13*Derivative(Phi(X1, X2, X3), (X1, 2), X3) + I22*Derivative(Phi(X1, X2, X3), X1, (X2, 2))/2 + I23*Derivative(Phi(X1, X2, X3), X1, X2, X3) + I33*Derivative(Phi(X1, X2, X3), X1, (X3, 2))/2 + M*Derivative(Phi(X1, X2, X3), X1)
# EL_2 = A2*M + I11*Derivative(Phi(X1, X2, X3), (X1, 2), X2)/2 + I12*Derivative(Phi(X1, X2, X3), X1, (X2, 2)) + I13*Derivative(Phi(X1, X2, X3), X1, X2, X3) + I22*Derivative(Phi(X1, X2, X3), (X2, 3))/2 + I23*Derivative(Phi(X1, X2, X3), (X2, 2), X3) + I33*Derivative(Phi(X1, X2, X3), X2, (X3, 2))/2 + M*Derivative(Phi(X1, X2, X3), X2)
# EL_3 = A3*M + I11*Derivative(Phi(X1, X2, X3), (X1, 2), X3)/2 + I12*Derivative(Phi(X1, X2, X3), X1, X2, X3) + I13*Derivative(Phi(X1, X2, X3), X1, (X3, 2)) + I22*Derivative(Phi(X1, X2, X3), (X2, 2), X3)/2 + I23*Derivative(Phi(X1, X2, X3), X2, (X3, 2)) + I33*Derivative(Phi(X1, X2, X3), (X3, 3))/2 + M*Derivative(Phi(X1, X2, X3), X3)
#
# === COM acceleration law (lambda-free) ===
# a_1 = (-I11*Derivative(Phi(X1, X2, X3), (X1, 3))/2 - I12*Derivative(Phi(X1, X2, X3), (X1, 2), X2) - I13*Derivative(Phi(X1, X2, X3), (X1, 2), X3) - I22*Derivative(Phi(X1, X2, X3), X1, (X2, 2))/2 - I23*Derivative(Phi(X1, X2, X3), X1, X2, X3) - I33*Derivative(Phi(X1, X2, X3), X1, (X3, 2))/2 - M*Derivative(Phi(X1, X2, X3), X1))/M
# a_2 = (-I11*Derivative(Phi(X1, X2, X3), (X1, 2), X2)/2 - I12*Derivative(Phi(X1, X2, X3), X1, (X2, 2)) - I13*Derivative(Phi(X1, X2, X3), X1, X2, X3) - I22*Derivative(Phi(X1, X2, X3), (X2, 3))/2 - I23*Derivative(Phi(X1, X2, X3), (X2, 2), X3) - I33*Derivative(Phi(X1, X2, X3), X2, (X3, 2))/2 - M*Derivative(Phi(X1, X2, X3), X2))/M
# a_3 = (-I11*Derivative(Phi(X1, X2, X3), (X1, 2), X3)/2 - I12*Derivative(Phi(X1, X2, X3), X1, X2, X3) - I13*Derivative(Phi(X1, X2, X3), X1, (X3, 2)) - I22*Derivative(Phi(X1, X2, X3), (X2, 2), X3)/2 - I23*Derivative(Phi(X1, X2, X3), X2, (X3, 2)) - I33*Derivative(Phi(X1, X2, X3), (X3, 3))/2 - M*Derivative(Phi(X1, X2, X3), X3))/M
#
# === Uniform sphere check ===
# M_sphere = 4*pi*R**3*rho_0/3
# I_uniform = Matrix([
# [M_sphere*R**2/5,               0,               0],
# [              0, M_sphere*R**2/5,               0],
# [              0,               0, M_sphere*R**2/5]])
# Q_uniform = Matrix([
# [0, 0, 0],
# [0, 0, 0],
# [0, 0, 0]])
#
# === n=1 polytrope check ===
# rho_n1(r) = R*rho_c*sin(pi*r/R)/(pi*r)
# M_poly = 4*R**3*rho_c/pi
# I_n1 = Matrix([
# [M_poly*R**2*(-6 + pi**2)/(3*pi**2),                                  0,                                  0],
# [                                 0, M_poly*R**2*(-6 + pi**2)/(3*pi**2),                                  0],
# [                                 0,                                  0, M_poly*R**2*(-6 + pi**2)/(3*pi**2)]])
# Q_n1 = Matrix([
# [0, 0, 0],
# [0, 0, 0],
# [0, 0, 0]])
