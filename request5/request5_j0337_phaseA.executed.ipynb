# %% [markdown]
# # Request 5 Phase A: J0337 Published-Bound Translation
#
# This notebook runs the strong-field posterior translation from published `Delta` bounds to `(sigma1, sigma2)`.

# %%
import json
from pathlib import Path

import request5_j0337_phaseA as r5

result = r5.run_phase_a('.')
r5.print_summary(result['summary'])
# Out:
# === J0337 Phase A translation ===
# optimistic: input Voisin et al. (2025), A&A 693, A143, |Delta| < 1.5e-6 (95% CL, planet hypothesis)
# conservative: input Voisin et al. (2025), A&A 693, A143, |Delta| < 2.3e-6 (95% CL, red-noise hypothesis)
# optimistic: conditional(|sigma1|,|sigma2|)_95 = (1.150e-05, 1.000e-04) [data-driven]; joint marginals |sigma1|_95 = 4.700e-05, |sigma2|_95 = 3.567e-04 [box-conditional]
# conservative: conditional(|sigma1|,|sigma2|)_95 = (1.750e-05, 1.533e-04) [data-driven]; joint marginals |sigma1|_95 = 4.700e-05, |sigma2|_95 = 3.567e-04 [box-conditional]
#
# === Prior-box scale check (wide EOS prior) ===
# optimistic box x1: marginal(|s1|,|s2|)_95 = (4.700e-05, 3.567e-04), conditional = (1.150e-05, 1.000e-04)
# optimistic box x2: marginal(|s1|,|s2|)_95 = (9.300e-05, 7.133e-04), conditional = (1.100e-05, 1.000e-04)
# optimistic box x4: marginal(|s1|,|s2|)_95 = (1.860e-04, 1.440e-03), conditional = (1.200e-05, 9.333e-05)
# optimistic: x4 growth marginal(s1,s2) = (3.96, 4.04), conditional = (1.04, 0.93) -> marginals box-limited: True, conditionals box-limited: False
# conservative box x1: marginal(|s1|,|s2|)_95 = (4.700e-05, 3.567e-04), conditional = (1.750e-05, 1.533e-04)
# conservative box x2: marginal(|s1|,|s2|)_95 = (9.300e-05, 7.133e-04), conditional = (1.700e-05, 1.533e-04)
# conservative box x4: marginal(|s1|,|s2|)_95 = (1.860e-04, 1.440e-03), conditional = (1.800e-05, 1.467e-04)
# conservative: x4 growth marginal(s1,s2) = (3.96, 4.04), conditional = (1.03, 0.96) -> marginals box-limited: True, conditionals box-limited: False
#
# === EOS sensitivity (95% bounds) ===
# low [0.10, 0.15]: opt(|s1|,|s2|)=(4.600e-05, 3.700e-04), cons(|s1|,|s2|)=(4.600e-05, 3.700e-04)
# wide [0.10, 0.20]: opt(|s1|,|s2|)=(4.700e-05, 3.567e-04), cons(|s1|,|s2|)=(4.700e-05, 3.567e-04)
# high [0.15, 0.20]: opt(|s1|,|s2|)=(4.750e-05, 2.900e-04), cons(|s1|,|s2|)=(4.750e-05, 3.000e-04)

# %%
summary = json.loads(Path('request5_j0337_phaseA_summary.json').read_text())
summary['bounds']['optimistic']['wide']['stats']
# Out:
# {'sigma1': {'mean': -1.6940658945086007e-21,
#   'std': 2.780896155958168e-05,
#   'mode': -6.776263578034403e-21,
#   'abs_95': 4.7e-05,
#   'grid_abs_max': 5e-05,
#   'abs95_over_grid_max': 0.94},
#  'sigma2': {'mean': -1.3552527156068805e-20,
#   'std': 0.00020491245188792475,
#   'mode': 0.0,
#   'abs_95': 0.0003566666666666667,
#   'grid_abs_max': 0.0004,
#   'abs95_over_grid_max': 0.8916666666666667},
#  'sigma1_given_sigma2_eq_0': {'mean': 4.235164736271502e-22,
#   'std': 5.639528035303687e-06,
#   'mode': -6.776263578034403e-21,
#   'abs_95': 1.1499999999999988e-05,
#   'grid_abs_max': 5e-05,
#   'abs95_over_grid_max': 0.22999999999999976},
#  'sigma2_given_sigma1_eq_0': {'mean': 5.082197683525802e-20,
#   'std': 4.780327975479385e-05,
#   'mode': 0.0,
#   'abs_95': 9.999999999999999e-05,
#   'grid_abs_max': 0.0004,
#   'abs95_over_grid_max': 0.24999999999999997}}
