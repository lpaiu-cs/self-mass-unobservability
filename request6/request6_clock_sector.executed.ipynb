# %% [markdown]
# # Request 6: Clock-Sector Joint Gamma Fit
#
# This notebook executes the toy binary-pulsar clock-sector fit and reloads the summary products.

# %%
import json
from pathlib import Path

import request6_clock_sector as r6

result = r6.run_request6('.')
r6.print_summary(result['summary'])
# Out:
# === Observable model ===
# potential_only
#
# === Clock-only leave-one-out model ===
# zeta1 = 2.514e-03 ± 1.946e-02, |zeta1|_95 = 3.400e-02 [box-conditional]
# zeta2 = 2.538e-03 ± 1.438e-01, |zeta2|_95 = 2.375e-01 [box-conditional]
#
# === Effective combination actually seen by the current sample ===
# sbar(global) = 0.134, spread = 7.869e-04 (relative 0.586%)
# eta(sbar) = 3.831e-04 ± 6.482e-04, |eta(sbar)|_95 = 1.482e-03
# eta_* = 3.831e-04 ± 6.482e-04, |eta_*|_95 = 1.482e-03
# kappa_* = 3.195e-03 ± 2.033e-02, |kappa_*|_95 = 3.586e-02 [box-conditional]
# (cross-check: Fisher lever-arm audit gives data-driven |kappa_*|_95 = 8.416e+00)
#
# === Zeta prior-box scale check (clock-only) ===
# box x1: |zeta1|_95 = 3.400e-02, |zeta2|_95 = 2.375e-01, |eta(sbar)|_95 = 1.482e-03, |kappa_*|_95 = 3.586e-02, B(clock/tied_opt) = 1.604e-01
# box x2: |zeta1|_95 = 6.600e-02, |zeta2|_95 = 4.792e-01, |eta(sbar)|_95 = 1.723e-03, |kappa_*|_95 = 6.794e-02, B(clock/tied_opt) = 8.199e-02
# box x4: |zeta1|_95 = 1.320e-01, |zeta2|_95 = 9.583e-01, |eta(sbar)|_95 = 2.470e-03, |kappa_*|_95 = 1.341e-01, B(clock/tied_opt) = 4.286e-02
# x4 growth: zeta1 = 3.88, zeta2 = 4.04, eta(sbar) = 1.67, kappa_* = 3.74, BF = 0.27
#
# === System GR leave-one-out diagnostics ===
# PSR B1534+12: mp = 1.336075 ± 0.002213 Msun, mc = 1.342384 ± 0.002213 Msun, Xc = 0.501, gamma_obs/gamma_GR - 1 = 3.391e-03
# PSR J0737-3039A/B: mp = 1.338283 ± 0.002652 Msun, mc = 1.248892 ± 0.001259 Msun, Xc = 0.483, gamma_obs/gamma_GR - 1 = 1.309e-04
#
# === Tied model (zeta = sigma) ===
# tied_optimistic: |zeta1|_95 = 4.700e-05, |zeta2|_95 = 3.567e-04
# tied_conservative: |zeta1|_95 = 4.700e-05, |zeta2|_95 = 3.567e-04
#
# === Bayes factors (flat-prior Occam volume; box-conditional) ===
# B(clock/tied_opt) = 1.604e-01, B(clock/tied_cons) = 1.604e-01
#
# === Approximate compressed delta_gamma by system ===
# PSR B1534+12: delta_gamma ~= 2.543e-04 ± 4.301e-04, |delta_gamma|_95 = 9.834e-04
# PSR J0737-3039A/B: delta_gamma ~= 2.592e-04 ± 4.390e-04, |delta_gamma|_95 = 1.005e-03
#
# === System pulls (clock-only posterior mean) ===
# PSR B1534+12: pull = 1.418, gamma_obs/gamma_GR - 1 = 3.391e-03, self-gravity mean = 0.134
# PSR J0737-3039A/B: pull = -0.305, gamma_obs/gamma_GR - 1 = 1.309e-04, self-gravity mean = 0.135

# %%
summary = json.loads(Path('request6_clock_sector_summary.json').read_text())
summary['bayes_factors']
# Out:
# {'clock_over_tied_optimistic': 0.1603789027134541,
#  'clock_over_tied_conservative': 0.16037903341526052}

# %%
summary['models']['clock_only']['stats']
# Out:
# {'zeta1': {'mean': 0.0025140531053100155,
#   'std': 0.01946076928152856,
#   'mode': -0.013000000000000001,
#   'abs_95': 0.033999999999999996},
#  'zeta2': {'mean': 0.0025379492847366694,
#   'std': 0.14383971476342264,
#   'mode': 0.20833333333333331,
#   'abs_95': 0.2375}}

# %%
summary['effective_combinations']['global_sbar']
# Out:
# {'clock_only': {'sbar': 0.13419551590434078,
#   'mean': 0.00038307915198404485,
#   'std': 0.0006482321550867341,
#   'mode': 0.00028858755672131996,
#   'abs_95': 0.0014819868828921264,
#   'q16': -0.0002495896136341701,
#   'q84': 0.0010201888151131892,
#   'q025': -0.0008686722481030876,
#   'q975': 0.0016940418684417708},
#  'tied_optimistic': {'sbar': 0.13419551590434078,
#   'mean': 1.1179735543157498e-09,
#   'std': 1.0181935158123983e-06,
#   'mode': -9.093441867581209e-22,
#   'abs_95': 1.987742501639217e-06,
#   'q16': -1.0060836465999803e-06,
#   'q84': 1.0069766661926556e-06,
#   'q025': -1.9851644901842964e-06,
#   'q975': 1.988507947004369e-06},
#  'tied_conservative': {'sbar': 0.13419551590434078,
#   'mean': 1.8950827754442614e-09,
#   'std': 1.326166713445721e-06,
#   'mode': -9.093441867581209e-22,
#   'abs_95': 2.595093354256357e-06,
#   'q16': -1.2922125563292494e-06,
#   'q84': 1.2956835873768496e-06,
#   'q025': -2.5923877685739047e-06,
#   'q975': 2.595986373849031e-06}}

# %%
summary['effective_combinations']['linearized_basis']['clock_only']
# Out:
# {'sstar': 0.13419551590434078,
#  'eta_star': {'mean': 0.00038307915198404485,
#   'std': 0.0006482321550867341,
#   'mode': 0.00028858755672131996,
#   'abs_95': 0.0014819868828921264,
#   'q16': -0.0002495896136341701,
#   'q84': 0.0010201888151131892,
#   'q025': -0.0008686722481030876,
#   'q975': 0.0016940418684417708},
#  'kappa_star': {'mean': 0.0031952159325185966,
#   'std': 0.020325604779555913,
#   'mode': -0.00036566517974611756,
#   'abs_95': 0.03586065774514334,
#   'q16': -0.01988221230941853,
#   'q84': 0.026291240755359026,
#   'q025': -0.03155991039586681,
#   'q975': 0.03840953672122854}}

# %%
summary['models']['clock_only']['pulls']
# Out:
# [{'name': 'PSR B1534+12',
#   'gamma_obs_s': 0.0020708,
#   'gamma_model_s': 0.002064327327324561,
#   'gamma_model_std_s': 4.537567127442382e-06,
#   'gamma_gr_s': 0.002063801946283937,
#   'pull': 1.4178811765885881,
#   'mp_mean_msun': 1.336075444977067,
#   'mc_mean_msun': 1.3423840590864808,
#   'self_gravity_mean': 0.13380206328465855},
#  {'name': 'PSR J0737-3039A/B',
#   'gamma_obs_s': 0.000384045,
#   'gamma_model_s': 0.0003840943399088441,
#   'gamma_model_std_s': 1.3178828405457713e-07,
#   'gamma_gr_s': 0.0003839947183853644,
#   'pull': -0.30479882563037347,
#   'mp_mean_msun': 1.3382829883128577,
#   'mc_mean_msun': 1.2488921553624532,
#   'self_gravity_mean': 0.13458896852402302}]
