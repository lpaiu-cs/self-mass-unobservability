# %% [markdown]
# # Request 6 Follow-up: Lever-Arm Audit
#
# This notebook audits how much `s`-spread is needed to turn the current local clock-sector amplitude fit into a local slope measurement.

# %%
import json
from pathlib import Path

import request6_lever_arm_audit as audit

result = audit.run_lever_arm_audit('.')
audit.print_summary(result['summary'])
# Out:
# === Current linearized basis ===
# s* = 0.134196, |eta_*|_95 ~= 3.311e-03, |kappa_*|_95 ~= 8.416e+00
# slope proxy = 4.103e-01
#
# === Representative single-candidate scenarios ===
# sigma_delta = 1.0e-03: best s = 0.200, |ds| = 0.066, |kappa_*|_95 = 4.861e-02, improvement = 173.13x
# sigma_delta = 5.0e-04: best s = 0.200, |ds| = 0.066, |kappa_*|_95 = 2.909e-02, improvement = 289.32x
# sigma_delta = 2.0e-04: best s = 0.200, |ds| = 0.066, |kappa_*|_95 = 2.046e-02, improvement = 411.26x
# sigma_delta = 1.0e-04: best s = 0.200, |ds| = 0.066, |kappa_*|_95 = 1.894e-02, improvement = 444.40x
#
# === Representative symmetric-pair scenarios ===
# sigma_delta = 1.0e-03: best |ds| = 0.054, |kappa_*|_95 = 3.841e-02, improvement = 219.08x
# sigma_delta = 5.0e-04: best |ds| = 0.054, |kappa_*|_95 = 1.924e-02, improvement = 437.50x
# sigma_delta = 2.0e-04: best |ds| = 0.054, |kappa_*|_95 = 7.649e-03, improvement = 1100.25x
# sigma_delta = 1.0e-04: best |ds| = 0.054, |kappa_*|_95 = 3.830e-03, improvement = 2197.24x

# %%
summary = json.loads(Path('request6_lever_arm_audit_summary.json').read_text())
summary['current_basis_gaussian']
# Out:
# {'sstar': 0.13419551590434076,
#  'covariance': [[2.8541602562965792e-06, -0.006757640919899775],
#   [-0.006757640919899775, 18.437136534575153]],
#  'std_eta_star': 0.0016894260138569487,
#  'std_kappa_star': 4.293848685570459,
#  'abs95_eta_star': 0.0033112749871596196,
#  'abs95_kappa_star': 8.4159434237181,
#  'correlation': -0.9315564943983159}

# %%
summary['representative_rows']
# Out:
# [{'sigma_delta': 0.0010014833820379042,
#   'best_s': 0.2,
#   'best_abs_ds': 0.06580448409565925,
#   'kappa95': 0.048610216548465264,
#   'improvement': 173.13116503661843},
#  {'sigma_delta': 0.0005014844822490394,
#   'best_s': 0.2,
#   'best_abs_ds': 0.06580448409565925,
#   'kappa95': 0.029088357988729108,
#   'improvement': 289.32342715869464},
#  {'sigma_delta': 0.0001994079648317803,
#   'best_s': 0.2,
#   'best_abs_ds': 0.06580448409565925,
#   'kappa95': 0.020463888541741877,
#   'improvement': 411.25827120057886},
#  {'sigma_delta': 9.985188151251339e-05,
#   'best_s': 0.2,
#   'best_abs_ds': 0.06580448409565925,
#   'kappa95': 0.0189376096586687,
#   'improvement': 444.4036800529203}]

# %%
summary['representative_pair_rows']
# Out:
# [{'sigma_delta': 0.0010014833820379042,
#   'best_s': 0.1883910318086815,
#   'best_abs_ds': 0.054195515904340755,
#   'kappa95': 0.03841499296021119,
#   'improvement': 219.0796554989615},
#  {'sigma_delta': 0.0005014844822490394,
#   'best_s': 0.1883910318086815,
#   'best_abs_ds': 0.054195515904340755,
#   'kappa95': 0.01923627983999304,
#   'improvement': 437.50369061594733},
#  {'sigma_delta': 0.0001994079648317803,
#   'best_s': 0.1883910318086815,
#   'best_abs_ds': 0.054195515904340755,
#   'kappa95': 0.007649098381508748,
#   'improvement': 1100.252997668739},
#  {'sigma_delta': 9.985188151251339e-05,
#   'best_s': 0.1883910318086815,
#   'best_abs_ds': 0.054195515904340755,
#   'kappa95': 0.0038302303989053046,
#   'improvement': 2197.2420839549}]
