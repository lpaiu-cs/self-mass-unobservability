# %% [markdown]
# # Request 3: LLR Mock Injection-Recovery
#
# This notebook executes the toy Sun-Earth-Moon mock LLR pipeline and reloads the summary products.

# %%
import json
from pathlib import Path

import request3_llr_mock as r3

result = r3.run_request3('.')
r3.print_summary(result['summary'])
# Out:
# === Analytic weak-field benchmark ===
# A_cosD ≈ (13.1) sigma1 + (6.32468e-09) sigma2 [m]
#
# === Scenario summary ===
# null: inj=(0.000e+00, 0.000e+00), mean=(1.817e-05 ± 6.243e-05, -4.902e+04 ± 1.065e+05), mode=(4.000e-05, -2.000e+05), AcosD[inj/fit/analytic]=(0.000e+00, 5.734e-05, 0.000e+00) m, max|resid|=15.41 mm
# injected: inj=(5.000e-04, 0.000e+00), mean=(4.415e-04 ± 6.377e-05, 3.327e+04 ± 1.097e+05), mode=(4.200e-04, 1.950e+05), AcosD[inj/fit/analytic]=(5.809e-03, 5.446e-03, 6.550e-03) m, max|resid|=13.40 mm

# %%
summary = json.loads(Path('request3_llr_mock_summary.json').read_text())
summary
# Out:
# {'config': {'dt': 21600.0,
#   'duration_days': 720,
#   'output_step_days': 1,
#   'range_noise_sigma_m': 0.005,
#   'rng_seed': 20260422},
#  'analytic_coefficients_m': {'sigma1': 13.1, 'sigma2': 6.32468e-09},
#  'scenarios': [{'name': 'null',
#    'injected_sigma1': 0.0,
#    'injected_sigma2': 0.0,
#    'recovered_sigma1_mean': 1.8166723519536833e-05,
#    'recovered_sigma1_std': 6.242517373117142e-05,
#    'recovered_sigma2_mean': -49021.89160278639,
#    'recovered_sigma2_std': 106463.55480771352,
#    'map_sigma1': 3.9999999999999996e-05,
#    'map_sigma2': -200000.0,
#    'analytic_cosD_amplitude_m': 0.0,
#    'injected_cosD_amplitude_m': 0.0,
#    'fit_cosD_amplitude_m': 5.734407118923008e-05,
#    'max_abs_residual_mm': 15.406012535095215},
#   {'name': 'injected',
#    'injected_sigma1': 0.0005,
#    'injected_sigma2': 0.0,
#    'recovered_sigma1_mean': 0.00044152448724649223,
#    'recovered_sigma1_std': 6.377467038536615e-05,
#    'recovered_sigma2_mean': 33270.21695389397,
#    'recovered_sigma2_std': 109748.4463058775,
#    'map_sigma1': 0.0004200000000000001,
#    'map_sigma2': 195000.0,
#    'analytic_cosD_amplitude_m': 0.00655,
#    'injected_cosD_amplitude_m': 0.005809381195703057,
#    'fit_cosD_amplitude_m': 0.005445583722350116,
#    'max_abs_residual_mm': 13.398826122283936}]}

# %%
summary['analytic_coefficients_m']
# Out:
# {'sigma1': 13.1, 'sigma2': 6.32468e-09}
