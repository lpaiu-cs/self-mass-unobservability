# %% [markdown]
# # Request 2: Internal-Structure Consistency
#
# This notebook reproduces the Newtonian consistency check for literal self-gravity removal with `alpha = 1 - lambda`.

# %%
import request2_internal_structure as r2

uniform = r2.uniform_sphere_symbolic()
poly = r2.n1_polytrope_symbolic()
uniform["Pc"], uniform["Eg"], poly["R"], poly["rho_c"], poly["Eg"]
# Out:
# (3*G*M**2*(1 - lambda)/(8*pi*R**4),
#  3*G*M**2*(lambda - 1)/(5*R),
#  sqrt(pi)*sqrt(K)*sqrt(1/(2 - 2*lambda))/sqrt(G),
#  sqrt(2)*G**(3/2)*M*(1 - lambda)**(3/2)/(2*sqrt(pi)*K**(3/2)),
#  3*sqrt(2)*G**(3/2)*M**2*(lambda - 1)/(4*sqrt(pi)*sqrt(K)*sqrt(-1/(lambda - 1))))

# %%
r2.n1_hydrostatic_residual_symbolic()
# Out:
# 0

# %%
r2.main('.')
# Out:
# === Uniform sphere toy ===
# rho = 3*M/(4*pi*R**3)
# Pc = 3*G*M**2*(1 - lambda)/(8*pi*R**4)
# Eg = 3*G*M**2*(lambda - 1)/(5*R)
# Pi = G*M**2*(1 - lambda)/(5*R)
# virial_residual = 0
#
# === n=1 polytrope with fixed M and K ===
# R = sqrt(2)*sqrt(pi)*sqrt(K)*sqrt(-1/(lambda - 1))/(2*sqrt(G))
# rho_c = sqrt(2)*G**(3/2)*M*(1 - lambda)**(3/2)/(2*sqrt(pi)*K**(3/2))
# Pc = -G**3*M**2*(lambda - 1)**3/(2*pi*K**2)
# Eg = 3*sqrt(2)*G**(3/2)*M**2*(lambda - 1)/(4*sqrt(pi)*sqrt(K)*sqrt(-1/(lambda - 1)))
# Pi = sqrt(2)*G**(3/2)*M**2*(1 - lambda)/(4*sqrt(pi)*sqrt(K)*sqrt(-1/(lambda - 1)))
# virial_residual = 0
#
# === n=1 hydrostatic residual ===
# 0
#
# === lambda -> 1 asymptotics (alpha = 1 - lambda -> 0+) ===
# uniform: Pc ~ alpha, |Eg| ~ alpha, Pi ~ alpha
# n=1 fixed M,K: R ~ alpha^(-1/2), rho_c ~ alpha^(3/2), Pc ~ alpha^3, |Eg| ~ alpha^(3/2)
#
# wrote request2_internal_structure_scalings.tsv
# wrote request2_internal_structure_scalings.svg
